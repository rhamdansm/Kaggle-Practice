# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -q kaggle

# %%
# !cp '/content/gdrive/MyDrive/kaggle Competition/kaggle.json' 'kaggle.json'

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d akshaypawar7/millions-of-movies
# Out:
# Downloading millions-of-movies.zip to /content
#  98% 167M/170M [00:06<00:00, 31.4MB/s]
# 100% 170M/170M [00:06<00:00, 26.2MB/s]

# %%
! unzip /content/millions-of-movies.zip
# Out:
# Archive:  /content/millions-of-movies.zip
#   inflating: movies.csv

# %% [markdown]
# ## Import Library

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances

pd.options.mode.chained_assignment = None

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Data Understanding

# %%
data = pd.read_csv("/content/movies.csv")
data.head(2)
# Out:
#        id                          title                            genres  \
# 0  610150  Dragon Ball Super: Super Hero  Animation-Science Fiction-Action
# 1  616037         Thor: Love and Thunder          Action-Adventure-Fantasy
#
#   original_language                                           overview  \
# 0                ja  The Red Ribbon Army an evil organization that ...
# 1                en  After his retirement is interrupted by Gorr th...
#
#    popularity                               production_companies release_date  \
# 0   16585.915  Shueisha-Fuji Television Network-Toei Animatio...   2022-06-11
# 1    5372.967             Marvel Studios-Kevin Feige Productions   2022-07-06
#
#         budget      revenue  runtime    status  \
# 0          0.0   70000000.0     99.0  Released
# 1  250000000.0  746900000.0    119.0  Released
#
#                                    tagline  vote_average  vote_count  \
# 0  A super awakening and calamity is born.         7.953       985.0
# 1                 The one is not the only.         6.755      2224.0
#
#                                              credits  \
# 0  Masako Nozawa-Toshio Furukawa-Yuko Minaguchi-H...
# 1  Chris Hemsworth-Natalie Portman-Christian Bale...
#
#                                             keywords  \
# 0  android-sequel-attack-based on manga-fighting-...
# 1  ex-girlfriend-hero-greek mythology-sequel-supe...
#
#                         poster_path                     backdrop_path  \
# 0  /rugyJdeoJm7cSJL1q4jBpTNbxyU.jpg  /ugS5FVfCI3RV0ZwZtBV3HAV75OX.jpg
# 1  /pIkRyD18kl4FhoCNQuWxWu5cBLM.jpg  /vvObT0eIWGlArLQx3K5wZ0uT812.jpg
#
#                                      recommendations
# 0  507086-629015-616037-810693-361743-438148-7788...
# 1  2-438148-45920-507086-361743-919355-748918-718...

# %%
data = data.loc[:5000, ["title", "genres", "overview"]]
data.head()
# Out:
#                            title  \
# 0  Dragon Ball Super: Super Hero
# 1         Thor: Love and Thunder
# 2                      Samaritan
# 3        DC League of Super-Pets
# 4                           Prey
#
#                                            genres  \
# 0                Animation-Science Fiction-Action
# 1                        Action-Adventure-Fantasy
# 2                    Action-Drama-Science Fiction
# 3  Animation-Action-Family-Science Fiction-Comedy
# 4                                 Thriller-Action
#
#                                             overview
# 0  The Red Ribbon Army an evil organization that ...
# 1  After his retirement is interrupted by Gorr th...
# 2  Thirteen year old Sam Cleary  suspects that hi...
# 3  When Superman and the rest of the Justice Leag...
# 4  When danger threatens her camp the fierce and ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     5001 non-null   object
#  1   genres    4940 non-null   object
#  2   overview  4940 non-null   object
# dtypes: object(3)
# memory usage: 117.3+ KB

# %%
data.isnull().sum()
# Out:
# title        0
# genres      61
# overview    61
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# title       0
# genres      0
# overview    0
# dtype: int64

# %%
data[data["title"].duplicated()].count()
# Out:
# title       348
# genres      348
# overview    348
# dtype: int64

# %%
data = data.drop_duplicates(subset=["title"])

# %%
data[data["title"].duplicated()].count()
# Out:
# title       0
# genres      0
# overview    0
# dtype: int64

# %% [markdown]
# ## Vectorize

# %%
def Vectorize(data, column, cosine):
  # Inisialisasi TfidfVectorizer
  tf = TfidfVectorizer()
  
  # Melakukan perhitungan idf pada data cuisine
  tf.fit(data[column])

  # Melakukan fit lalu ditransformasikan ke bentuk matrix
  tfidf_matrix = tf.fit_transform(data[column]) 
  
  if cosine == 0:
    cosine_dis =  cosine_distances(tfidf_matrix)
    cosine_dis_df = pd.DataFrame(cosine_dis, index=data['title'], columns=data['title'])
    return cosine_dis_df
  else :
    cosine_sim = cosine_similarity(tfidf_matrix)
    cosine_sim_df = pd.DataFrame(cosine_sim, index=data['title'], columns=data['title'])
    return cosine_sim_df

# %%
cosine_dis_overview = Vectorize(data, "overview", 0)
cosine_dis_overview
# Out:
# title                           Dragon Ball Super: Super Hero  \
# title
# Dragon Ball Super: Super Hero                        0.000000
# Thor: Love and Thunder                               0.937992
# Samaritan                                            0.955249
# DC League of Super-Pets                              0.966862
# Prey                                                 0.973043
# ...                                                       ...
# Toc Toc                                              0.965896
# Book of Shadows: Blair Witch 2                       0.962312
# Wander                                               0.975552
# Red Eye                                              0.965107
# Problem Child                                        0.984409
#
# title                           Thor: Love and Thunder  Samaritan  \
# title
# Dragon Ball Super: Super Hero                 0.937992   0.955249
# Thor: Love and Thunder                        0.000000   0.948120
# Samaritan                                     0.948120   0.000000
# DC League of Super-Pets                       0.936445   0.957175
# Prey                                          0.984319   0.966454
# ...                                                ...        ...
# Toc Toc                                       0.973925   0.975243
# Book of Shadows: Blair Witch 2                0.955188   0.960385
# Wander                                        0.954455   0.950642
# Red Eye                                       0.971530   0.971487
# Problem Child                                 0.984737   0.966862
#
# title                           DC League of Super-Pets      Prey      Nope  \
# title
# Dragon Ball Super: Super Hero                  0.966862  0.973043  0.988657
# Thor: Love and Thunder                         0.936445  0.984319  0.993477
# Samaritan                                      0.957175  0.966454  0.992473
# DC League of Super-Pets                        0.000000  0.972676  0.996032
# Prey                                           0.972676  0.000000  0.995836
# ...                                                 ...       ...       ...
# Toc Toc                                        0.970134  0.987714  0.993916
# Book of Shadows: Blair Witch 2                 0.956034  0.959824  0.989063
# Wander                                         0.957295  0.983363  0.986336
# Red Eye                                        0.957551  0.956479  0.989949
# Problem Child                                  0.991540  0.971602  1.000000
#
# title                           Top Gun: Maverick  Jurassic World Dominion  \
# title
# Dragon Ball Super: Super Hero            0.970605                 0.916958
# Thor: Love and Thunder                   0.957560                 0.949468
# Samaritan                                0.951112                 0.950124
# DC League of Super-Pets                  0.962260                 0.958085
# Prey                                     0.992326                 0.983229
# ...                                           ...                      ...
# Toc Toc                                  0.975448                 0.982105
# Book of Shadows: Blair Witch 2           0.973986                 0.970146
# Wander                                   0.959489                 0.975487
# Red Eye                                  0.985878                 0.989081
# Problem Child                            0.992454                 0.984771
#
# title                                RRR  Minions: The Rise of Gru  ...  \
# title                                                               ...
# Dragon Ball Super: Super Hero   0.990217                  0.964687  ...
# Thor: Love and Thunder          0.962779                  0.960145  ...
# Samaritan                       0.950857                  0.955027  ...
# DC League of Super-Pets         0.976706                  0.962225  ...
# Prey                            0.996225                  0.979848  ...
# ...                                  ...                       ...  ...
# Toc Toc                         0.988558                  0.973095  ...
# Book of Shadows: Blair Witch 2  0.968958                  0.945731  ...
# Wander                          0.981740                  0.959363  ...
# Red Eye                         0.989500                  0.984723  ...
# Problem Child                   0.989187                  0.989257  ...
#
# title                           The Family  Old School  Secret Obsession  \
# title
# Dragon Ball Super: Super Hero     0.981224    0.984089          0.965720
# Thor: Love and Thunder            0.978954    0.992728          0.967119
# Samaritan                         0.971214    0.996443          0.945900
# DC League of Super-Pets           0.973949    0.983991          0.957357
# Prey                              0.991324    0.995764          0.934404
# ...                                    ...         ...               ...
# Toc Toc                           0.993143    1.000000          0.970998
# Book of Shadows: Blair Witch 2    0.982775    0.954057          0.949343
# Wander                            0.959541    0.981451          0.951570
# Red Eye                           0.981907    0.976307          0.866234
# Problem Child                     0.963202    1.000000          0.961510
#
# title                           Meg 2: The Trench  Mr. Nobody   Toc Toc  \
# title
# Dragon Ball Super: Super Hero            0.990506    0.974979  0.965896
# Thor: Love and Thunder                   0.973760    0.980313  0.973925
# Samaritan                                0.974407    0.959565  0.975243
# DC League of Super-Pets                  0.962596    0.982267  0.970134
# Prey                                     0.984250    0.989462  0.987714
# ...                                           ...         ...       ...
# Toc Toc                                  0.987552    0.986646  0.000000
# Book of Shadows: Blair Witch 2           0.975444    0.985354  0.943474
# Wander                                   0.971739    0.970451  0.949256
# Red Eye                                  0.924065    0.993624  0.990929
# Problem Child                            1.000000    0.924719  0.995963
#
# title                           Book of Shadows: Blair Witch 2    Wander  \
# title
# Dragon Ball Super: Super Hero                         0.962312  0.975552
# Thor: Love and Thunder                                0.955188  0.954455
# Samaritan                                             0.960385  0.950642
# DC League of Super-Pets                               0.956034  0.957295
# Prey                                                  0.959824  0.983363
# ...                                                        ...       ...
# Toc Toc                                               0.943474  0.949256
# Book of Shadows: Blair Witch 2                        0.000000  0.934361
# Wander                                                0.934361  0.000000
# Red Eye                                               0.951765  0.972746
# Problem Child                                         0.975581  0.996257
#
# title                            Red Eye  Problem Child
# title
# Dragon Ball Super: Super Hero   0.965107       0.984409
# Thor: Love and Thunder          0.971530       0.984737
# Samaritan                       0.971487       0.966862
# DC League of Super-Pets         0.957551       0.991540
# Prey                            0.956479       0.971602
# ...                                  ...            ...
# Toc Toc                         0.990929       0.995963
# Book of Shadows: Blair Witch 2  0.951765       0.975581
# Wander                          0.972746       0.996257
# Red Eye                         0.000000       0.990193
# Problem Child                   0.990193       0.000000
#
# [4546 rows x 4546 columns]

# %%
cosine_sim_genres = Vectorize(data, "genres", 1)
cosine_sim_genres
# Out:
# title                           Dragon Ball Super: Super Hero  \
# title
# Dragon Ball Super: Super Hero                        1.000000
# Thor: Love and Thunder                               0.197896
# Samaritan                                            0.787026
# DC League of Super-Pets                              0.825777
# Prey                                                 0.265795
# ...                                                       ...
# Toc Toc                                              0.000000
# Book of Shadows: Blair Witch 2                       0.000000
# Wander                                               0.000000
# Red Eye                                              0.000000
# Problem Child                                        0.000000
#
# title                           Thor: Love and Thunder  Samaritan  \
# title
# Dragon Ball Super: Super Hero                 0.197896   0.787026
# Thor: Love and Thunder                        1.000000   0.206316
# Samaritan                                     0.206316   1.000000
# DC League of Super-Pets                       0.163417   0.649908
# Prey                                          0.328942   0.277104
# ...                                                ...        ...
# Toc Toc                                       0.000000   0.000000
# Book of Shadows: Blair Witch 2                0.000000   0.000000
# Wander                                        0.000000   0.000000
# Red Eye                                       0.000000   0.000000
# Problem Child                                 0.000000   0.000000
#
# title                           DC League of Super-Pets      Prey      Nope  \
# title
# Dragon Ball Super: Super Hero                  0.825777  0.265795  0.478657
# Thor: Love and Thunder                         0.163417  0.328942  0.000000
# Samaritan                                      0.649908  0.277104  0.499024
# DC League of Super-Pets                        1.000000  0.219487  0.395264
# Prey                                           0.219487  1.000000  0.270154
# ...                                                 ...       ...       ...
# Toc Toc                                        0.355417  0.000000  0.000000
# Book of Shadows: Blair Witch 2                 0.000000  0.344506  0.784179
# Wander                                         0.000000  0.331353  0.526857
# Red Eye                                        0.000000  0.480481  0.562259
# Problem Child                                  0.355417  0.000000  0.000000
#
# title                           Top Gun: Maverick  Jurassic World Dominion  \
# title
# Dragon Ball Super: Super Hero            0.280476                 0.765498
# Thor: Love and Thunder                   0.347111                 0.473761
# Samaritan                                0.594381                 0.798070
# DC League of Super-Pets                  0.231610                 0.632130
# Prey                                     0.466207                 0.269524
# ...                                           ...                      ...
# Toc Toc                                  0.000000                 0.000000
# Book of Shadows: Blair Witch 2           0.000000                 0.000000
# Wander                                   0.000000                 0.000000
# Red Eye                                  0.000000                 0.000000
# Problem Child                            0.000000                 0.000000
#
# title                                RRR  Minions: The Rise of Gru  ...  \
# title                                                               ...
# Dragon Ball Super: Super Hero   0.280476                  0.255065  ...
# Thor: Love and Thunder          0.347111                  0.634955  ...
# Samaritan                       0.594381                  0.000000  ...
# DC League of Super-Pets         0.231610                  0.369822  ...
# Prey                            0.466207                  0.000000  ...
# ...                                  ...                       ...  ...
# Toc Toc                         0.000000                  0.447911  ...
# Book of Shadows: Blair Witch 2  0.000000                  0.000000  ...
# Wander                          0.000000                  0.000000  ...
# Red Eye                         0.000000                  0.000000  ...
# Problem Child                   0.000000                  0.447911  ...
#
# title                           The Family  Old School  Secret Obsession  \
# title
# Dragon Ball Super: Super Hero     0.189968    0.000000          0.000000
# Thor: Love and Thunder            0.235100    0.000000          0.000000
# Samaritan                         0.198051    0.000000          0.284120
# DC League of Super-Pets           0.338602    0.355417          0.000000
# Prey                              0.315764    0.000000          0.554208
# ...                                    ...         ...               ...
# Toc Toc                           0.511319    1.000000          0.000000
# Book of Shadows: Blair Witch 2    0.000000    0.000000          0.342045
# Wander                            0.425969    0.000000          0.328985
# Red Eye                           0.000000    0.000000          0.477047
# Problem Child                     0.511319    1.000000          0.000000
#
# title                           Meg 2: The Trench  Mr. Nobody   Toc Toc  \
# title
# Dragon Ball Super: Super Hero            0.771704    0.510485  0.000000
# Thor: Love and Thunder                   0.202299    0.292414  0.000000
# Samaritan                                0.804540    0.679913  0.000000
# DC League of Super-Pets                  0.637255    0.421547  0.355417
# Prey                                     0.615000    0.000000  0.000000
# ...                                           ...         ...       ...
# Toc Toc                                  0.000000    0.000000  1.000000
# Book of Shadows: Blair Witch 2           0.211871    0.000000  0.000000
# Wander                                   0.203782    0.000000  0.000000
# Red Eye                                  0.295496    0.000000  0.000000
# Problem Child                            0.000000    0.000000  1.000000
#
# title                           Book of Shadows: Blair Witch 2    Wander  \
# title
# Dragon Ball Super: Super Hero                         0.000000  0.000000
# Thor: Love and Thunder                                0.000000  0.000000
# Samaritan                                             0.000000  0.000000
# DC League of Super-Pets                               0.000000  0.000000
# Prey                                                  0.344506  0.331353
# ...                                                        ...       ...
# Toc Toc                                               0.000000  0.000000
# Book of Shadows: Blair Witch 2                        1.000000  0.671858
# Wander                                                0.671858  1.000000
# Red Eye                                               0.717003  0.285220
# Problem Child                                         0.000000  0.000000
#
# title                            Red Eye  Problem Child
# title
# Dragon Ball Super: Super Hero   0.000000       0.000000
# Thor: Love and Thunder          0.000000       0.000000
# Samaritan                       0.000000       0.000000
# DC League of Super-Pets         0.000000       0.355417
# Prey                            0.480481       0.000000
# ...                                  ...            ...
# Toc Toc                         0.000000       1.000000
# Book of Shadows: Blair Witch 2  0.717003       0.000000
# Wander                          0.285220       0.000000
# Red Eye                         1.000000       0.000000
# Problem Child                   0.000000       1.000000
#
# [4546 rows x 4546 columns]

# %% [markdown]
# ## Get Recomendation

# %%
def movie_recommendations(title, distance_data=cosine_dis_overview, similarity_data=cosine_sim_genres,items=data[["title", "genres", "overview"]], k=300):
 
    # Mengambil data dengan menggunakan argpartition untuk melakukan partisi secara tidak langsung sepanjang sumbu yang diberikan    
    # Dataframe diubah menjadi numpy
    # Range(start, stop, step)
    index_dis = distance_data.loc[:,title].to_numpy().argpartition(
        range(-1, -300, -1))

    index_sim = similarity_data.loc[:,title].to_numpy().argpartition(
        range(-1, -300, -1))
    
    # Mengambil data dengan similarity dan distance terbesar dari index yang ada
    closest_dis = distance_data.columns[index_dis[-1:-(300+2):-1]]
    closest_sim = similarity_data.columns[index_sim[-1:-(300+2):-1]]
    
    # Drop title agar nama resto yang dicari tidak muncul dalam daftar rekomendasi
    closest_dis = closest_dis.drop(title, errors='ignore')
    closest_sim = closest_sim.drop(title, errors='ignore')

    # Menggabungkan title yang di rekomendasikan berdasarkan overview dan genrenya
    closest = [x for x in tuple(closest_dis) if x in tuple(closest_sim)]
    
    # Pandas dataframe rekomendasi film
    rec_overview = data.set_index("title").loc[closest_dis, :].head()
    rec_genres = data.set_index("title").loc[closest_sim, :].head()
    full_rec = data.set_index("title").loc[closest, :].head()
    
    return rec_overview, rec_genres, full_rec

# %%
data[data.title.eq('Dragon Ball Super: Super Hero')]
# Out:
#                            title                            genres  \
# 0  Dragon Ball Super: Super Hero  Animation-Science Fiction-Action
#
#                                             overview
# 0  The Red Ribbon Army an evil organization that ...

# %%
rec_overview, rec_genres, full_rec = movie_recommendations('Dragon Ball Super: Super Hero')

# %%
rec_overview[]
# Out:
#                                         genres  \
# title
# Stranded                                 Drama
# American Horror House                   Horror
# The Legend of La Llorona      Family-Animation
# Just Say Yes                    Comedy-Romance
# mother!                   Drama-Horror-Mystery
#
#                                                                    overview
# title
# Stranded                  Tensions run high while food runs low as six i...
# American Horror House     On Halloween night a sorority house is overrun...
# The Legend of La Llorona  Leo San Juan el joven héroe de "La Leyenda de ...
# Just Say Yes              Incurable romantic Lotte finds her life upende...
# mother!                   A couple's relationship is tested when uninvit...

# %%
rec_genres
# Out:
#                                                           genres  \
# title
# Dragon Ball Z: Battle of Gods   Animation-Action-Science Fiction
# Planet Hulk                     Science Fiction-Animation-Action
# Justice League: Doom            Action-Animation-Science Fiction
# Justice League vs. Teen Titans  Science Fiction-Action-Animation
# Dragon Ball Z: Lord Slug        Action-Animation-Science Fiction
#
#                                                                          overview
# title
# Dragon Ball Z: Battle of Gods   The events of Battle of Gods take place some y...
# Planet Hulk                     When the Hulk's presence on Earth becomes too ...
# Justice League: Doom            An adaptation of Mark Waid's "Tower of Babel" ...
# Justice League vs. Teen Titans  Robin is sent by Batman to work with the Teen ...
# Dragon Ball Z: Lord Slug        A Super Namekian named Slug comes to invade Ea...

# %%
full_rec
# Out:
#                                                                   genres  \
# title
# Dragon Ball & Dr. Slump Special  Animation-Action-Comedy-Science Fiction
# Altered Carbon: Resleeved                      Animation-Science Fiction
# Suicide Squad: Hell to Pay              Science Fiction-Action-Animation
# Judge Dredd                                              Science Fiction
# Meg 2: The Trench                        Science Fiction-Action-Thriller
#
#                                                                           overview
# title
# Dragon Ball & Dr. Slump Special  A special continuous feature containing all of...
# Altered Carbon: Resleeved        On the planet Latimer Takeshi Kovacs must prot...
# Suicide Squad: Hell to Pay       Task Force X targets a powerful mystical objec...
# Judge Dredd                      In a dystopian future Dredd the most famous ju...
# Meg 2: The Trench                 Plot unknown. Sequel to the 2018 film 'The Meg'.
